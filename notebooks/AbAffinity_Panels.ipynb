# %% [markdown]
# # Ours — Publication Panels (self-contained)
# Nature-style multi-panel figures. **All bar/curve panels embed their exact numbers** (extracted from the result files at build time) — no runtime file dependency. Only the scatter and heatmap panels read raw data. 400 DPI PDF+PNG. 'Ours' uses one fixed colour throughout; comparators use the colour-blind-safe Okabe-Ito palette; ordered series use sequential colormaps.

# %%
import os, json, numpy as np, pandas as pd
import matplotlib, matplotlib.pyplot as plt
from matplotlib import cm
HERE=os.path.dirname(os.path.abspath('__file__'))
FIG=os.path.join(HERE,'figures_panels'); os.makedirs(FIG,exist_ok=True)
plt.rcParams.update({'font.family':'Arial','font.size':7,'axes.titlesize':8,'axes.labelsize':7,
  'xtick.labelsize':6,'ytick.labelsize':6,'legend.fontsize':6,'legend.frameon':False,
  'axes.spines.top':False,'axes.spines.right':False,'figure.dpi':400,'savefig.dpi':400,
  'savefig.bbox':'tight','pdf.fonttype':42,'axes.linewidth':0.7})
PKD=r'pK$_d$'
# fixed colours — every colour means one thing
OURS='#D55E00'      # Ours (fixed everywhere)
TWO='#0072B2'; CONCAT='#009E73'; MVSF='#999999'   # comparators (Okabe-Ito)
C2='#56B4E9'; C3='#CC79A7'; C4='#E69F00'          # extra categoricals
def seq(n,cmap='viridis',lo=0.15,hi=0.9): return [cm.get_cmap(cmap)(x) for x in np.linspace(lo,hi,n)]
def panel(ax,L): ax.text(-0.16,1.16,L,transform=ax.transAxes,fontsize=10,fontweight='bold',va='top',ha='left')
def save(fig,n):
    for e in ('pdf','png'): fig.savefig(os.path.join(FIG,f'{n}.{e}'),bbox_inches='tight')
    print('saved',n)
DATA=json.loads('''{
"arch": {
"pearson": {
"Ours": {
"random": [
0.85790355270295,
0.0056029626594189
],
"cold": [
0.5680133387516498,
0.0197920455592924
]
},
"Two-stream": {
"random": [
0.8145000490460348,
0.0267232197273433
],
"cold": [
0.5500925106347584,
0.1066884515974534
]
},
"Concat+MLP": {
"random": [
0.817084744864491,
0.0313047061701904
],
"cold": [
0.5487784123862458,
0.0840449902749203
]
}
},
"spearman": {
"Ours": {
"random": [
0.8438220058619056,
0.0088215241811328
],
"cold": [
0.5514909476473288,
0.015883844626902
]
},
"Two-stream": {
"random": [
0.8036724462693042,
0.027994345811064
],
"cold": [
0.5280063155822159,
0.0770132831540568
]
},
"Concat+MLP": {
"random": [
0.7871544619922772,
0.0460139581156397
],
"cold": [
0.5200644463589124,
0.0877967353465357
]
}
},
"rmse": {
"Ours": {
"random": [
0.6937530572376369,
0.0136271055332631
],
"cold": [
1.1015099106953352,
0.014938112751496
]
},
"Two-stream": {
"random": [
0.782862895596022,
0.0549457130396793
],
"cold": [
1.1007590778050012,
0.0706705110805346
]
},
"Concat+MLP": {
"random": [
0.7498175854295823,
0.0630298807937755
],
"cold": [
1.4446666238503905,
1.116422257414634
]
}
}
},
"fisher": {
"pearson": {
"overall": 0.8617310606971588,
"intra": 0.7481181604991528,
"intra_std": 0.6246224110937614
},
"spearman": {
"overall": 0.8504355546427266,
"intra": 0.6849660703632677,
"intra_std": 0.6244801607313256
},
"rmse": {
"overall": 0.6864791792906435,
"intra": 0.7723088742840215,
"intra_std": 0.6792940380549743
}
},
"nano": [
{
"subgroup": "Overall",
"n": 2575,
"pearson": 0.8617310606971588,
"spearman": 0.8504355546427266,
"rmse": 0.6864791792906435
},
{
"subgroup": "Antibody",
"n": 1913,
"pearson": 0.859504220945161,
"spearman": 0.8364959292226563,
"rmse": 0.6787927981959763
},
{
"subgroup": "Nanobody",
"n": 662,
"pearson": 0.8542562926001743,
"spearman": 0.8725512190176308,
"rmse": 0.7082220501491966
}
],
"nano_fold": {
"Overall": {
"pearson": [
0.8636330163677902,
0.020721297062623444
],
"spearman": [
0.849025049230131,
0.01654426177675082
],
"rmse": [
0.6844327607030313,
0.05262801774645301
],
"n": 2575
},
"Antibody": {
"pearson": [
0.8631893795828534,
0.027153935983180673
],
"spearman": [
0.8365968780322739,
0.02358230680610473
],
"rmse": [
0.673664412770575,
0.07981661639920562
],
"n": 1913
},
"Nanobody": {
"pearson": [
0.8600760668559608,
0.04141286344191567
],
"spearman": [
0.8728696517996072,
0.04172918045584057
],
"rmse": [
0.699755218276961,
0.11465647158891297
],
"n": 662
}
},
"mvsf": {
"sabdab": {
"ours": {
"pearson": [
0.5926593802241117,
0.0146107980709621
],
"spearman": [
0.581828058362287,
0.0135584696598755
],
"rmse": [
1.325978961406464,
0.0175922297378042
]
},
"mvsf": {
"pearson": 0.491,
"rmse": 1.839
}
},
"abbind": {
"ours": {
"pearson": [
0.7807106394824557,
0.0059157174947898
],
"spearman": [
0.752567332798592,
0.0084269806886469
],
"rmse": [
1.2877751087871527,
0.0087010263434329
]
},
"mvsf": {
"pearson": 0.739,
"rmse": 1.905
}
},
"skempi": {
"ours": {
"pearson": [
0.7221854400800679,
0.0103097271505031
],
"spearman": [
0.6555070706716014,
0.0145537741401717
],
"rmse": [
1.0214782468041754,
0.0146976327795889
]
},
"mvsf": {
"pearson": 0.671,
"rmse": 1.513
}
},
"benchmark": {
"ours": {
"pearson": [
0.5511015717171833,
0.0562204958981403
],
"spearman": [
0.5472451723461655,
NaN
],
"rmse": [
1.338811466005683,
NaN
]
},
"mvsf": {
"pearson": 0.467,
"rmse": 1.447
}
}
},
"transfer": {
"1mlc": {
"frac": [
0.0,
0.1,
0.2,
0.3
],
"pearson": [
0.1369554709611112,
0.0580272668866332,
0.2771477685638531,
0.4280881631013194
],
"pearson_std": [
0.0,
0.1686742205203917,
0.1227206113692174,
0.0494034994462523
],
"spearman": [
0.165649314924943,
0.0491387944533002,
0.2958700691691705,
0.4147155613504411
],
"spearman_std": [
0.0,
0.1842174081800684,
0.1117338338143098,
0.0356547162528117
],
"rmse": [
5.054734598108502,
3.1254228873517,
2.9894958824437468,
2.83047470952368
]
},
"1n8z": {
"frac": [
0.0,
0.1,
0.2,
0.3
],
"pearson": [
-0.3156818913500885,
0.6500114892533206,
0.6707985606080663,
0.6903645682833793
],
"pearson_std": [
0.0,
0.0587133064781545,
0.0102118382996881,
0.0255217017936873
],
"spearman": [
-0.3508757719955452,
0.6491242280044548,
0.6909250447166819,
0.6962370490364821
],
"spearman_std": [
0.0,
0.0659600015335189,
0.0106980784773948,
0.0444628194279487
],
"rmse": [
2.0130106285957123,
0.5639275846421038,
0.5228101813942029,
0.5145456405428693
]
},
"4fqi": {
"frac": [
0.0,
0.1,
0.2,
0.3
],
"pearson": [
0.4515606470880027,
0.8911270272653935,
0.9379142148142016,
0.966861677935877
],
"pearson_std": [
0.0,
0.0351835523302057,
0.0143846238195211,
0.0019814302996639
],
"spearman": [
0.4685851088692528,
0.8706229245950846,
0.9174025311019292,
0.950224892963682
],
"spearman_std": [
0.0,
0.0188733610496613,
0.0237054041335206,
0.0084549071366958
],
"rmse": [
0.7293601761592244,
0.2893960207236388,
0.2225801845359904,
0.1647694370376198
]
},
"koenig": {
"frac": [
0.0,
0.1,
0.2,
0.3
],
"pearson": [
-0.0968470241663457,
0.0359223200606103,
0.0843202625256831,
0.1637294734874811
],
"pearson_std": [
0.0,
0.021528844026583,
0.0439827827437884,
0.0421123660214598
],
"spearman": [
-0.0648467059810433,
-0.015282084840816,
0.0295434438777868,
0.1155812473346
],
"spearman_std": [
0.0,
0.0143395724254788,
0.0431660612642429,
0.0556359537678862
],
"rmse": [
1.918146122442484,
0.5622186826238907,
0.5553636363604042,
0.5473288006280156
]
},
"trastuzumab": {
"frac": [
0.0,
0.1,
0.2,
0.3
],
"pearson": [
0.1766918371603966,
0.1465247531584312,
0.144916828724694,
0.2546550414675492
],
"pearson_std": [
0.0,
0.1004675951852424,
0.085734734633984,
0.0185805737866345
],
"spearman": [
0.1378542114520226,
0.207484854406879,
0.2452999804572992,
0.3041597895673378
],
"spearman_std": [
0.0,
0.159926203939327,
0.0536072134916467,
0.0414031797315706
],
"rmse": [
125.71704617552231,
108.38441608553512,
106.93268681915902,
106.40605864700774
]
},
"warszawski": {
"frac": [
0.0,
0.1,
0.2,
0.3
],
"pearson": [
0.1396443366488385,
0.1828492440325616,
0.1719170413258604,
0.1779120285295361
],
"pearson_std": [
0.0,
0.0395773835064962,
0.0874397720259721,
0.0814806865305078
],
"spearman": [
0.2430763918424852,
0.2650851373651404,
0.0526384731555485,
0.0632394415033249
],
"spearman_std": [
0.0,
0.0451630856357912,
0.1477957074008458,
0.1406485546176735
],
"rmse": [
3.070080469732124,
1.294390155925415,
1.2980094513143423,
1.2770700097148056
]
}
},
"gating": {
"learned": {
"pearson": [
0.8645612805988488,
0.0239543395138338
],
"spearman": [
0.8514707407882158,
0.024493068450494
],
"rmse": [
0.6795389227728363,
0.0676280583177289
]
},
"fixed": {
"pearson": [
0.8582602817908253,
0.0278570764784789
],
"spearman": [
0.8397892082035738,
0.0254747035483788
],
"rmse": [
0.6577843777523931,
0.0746403239758142
]
},
"open": {
"pearson": [
0.8461598511078223,
0.0300651901668611
],
"spearman": [
0.8391812951080763,
0.02720158094089
],
"rmse": [
0.7507024303515413,
0.085691169785896
]
},
"random": {
"pearson": [
0.8397378025068063,
0.0275700563579067
],
"spearman": [
0.8161503576258051,
0.0276483473821445
],
"rmse": [
0.6914493837275584,
0.0696476616769484
]
},
"closed": {
"pearson": [
0.5602613703648364,
0.0487655328937715
],
"spearman": [
0.4926302696035382,
0.0487261444485486
],
"rmse": [
1.120812178855696,
0.0718548258631824
]
}
},
"stream": [
{
"condition": "full",
"pearson": 0.8645612805988488,
"pearson_std": 0.0239543395138338,
"spearman": 0.8514707407882158,
"spearman_std": 0.02449306845049392,
"rmse": 0.6795389227728363,
"rmse_std": 0.06762805831772893
},
{
"condition": "zero_light",
"pearson": 0.7777453744348941,
"pearson_std": 0.0425016572483164,
"spearman": 0.7577830785174352,
"spearman_std": 0.03270328523629204,
"rmse": 0.8792547130353071,
"rmse_std": 0.12530077750937302
},
{
"condition": "zero_heavy",
"pearson": 0.6117781065011565,
"pearson_std": 0.0457681352960034,
"spearman": 0.589730703570922,
"spearman_std": 0.052244959763105,
"rmse": 1.0645633777287848,
"rmse_std": 0.10895708861264197
},
{
"condition": "zero_antigen",
"pearson": 0.6166988958892424,
"pearson_std": 0.0451121115814559,
"spearman": 0.5761786233097694,
"spearman_std": 0.03631990961748198,
"rmse": 1.0291917638886006,
"rmse_std": 0.07068629184249224
},
{
"condition": "mean_antigen",
"pearson": 0.5467045593884896,
"pearson_std": 0.0512225460191918,
"spearman": 0.4858838036450456,
"spearman_std": 0.0521881086542995,
"rmse": 1.2143770575060606,
"rmse_std": 0.10528744811755883
},
{
"condition": "shuffled_antigen",
"pearson": 0.3736510462265932,
"pearson_std": 0.0575517720117105,
"spearman": 0.323066152056546,
"spearman_std": 0.06749086459479708,
"rmse": 1.3157456298403378,
"rmse_std": 0.06557136478118641
}
],
"cdrreg": [
{
"cdr": "CDR-H1",
"pearson": 0.5522861777470249,
"spearman": 0.5503219416863785,
"rmse": 0.2660338043343305,
"pearson_std": 0.0090754762785564,
"spearman_std": 0.0084820614528404,
"rmse_std": 0.0038436791585726
},
{
"cdr": "CDR-H2",
"pearson": 0.5893405552974006,
"spearman": 0.6197105290102538,
"rmse": 0.2481297823952283,
"pearson_std": 0.0108170553137996,
"spearman_std": 0.0097130962345209,
"rmse_std": 0.005029695591427
},
{
"cdr": "CDR-H3",
"pearson": 0.4921335876282943,
"spearman": 0.4960713324313719,
"rmse": 0.2722938829775994,
"pearson_std": 0.0128807287425872,
"spearman_std": 0.0128491229861236,
"rmse_std": 0.0051776404218127
}
],
"topk": {
"k": [
0.05,
0.1,
0.2,
0.3
],
"random": [
0.05,
0.1,
0.2,
0.3
],
"meanpool": [
0.2325581395348837,
0.2558139534883721,
0.3546511627906977,
0.5019305019305019
],
"ours": [
0.2325581395348837,
0.2674418604651162,
0.4069767441860465,
0.5173745173745173
],
"zeroshot": [
0.0465116279069767,
0.0813953488372093,
0.1802325581395348,
0.3281853281853282
]
},
"plm": {
"ESM-2": {
"pearson": [
0.8376877951355663,
0.0282848192855107
],
"spearman": [
0.8220807533292916,
0.0331393830731828
],
"rmse": [
0.7268155817693482,
0.0451723113227673
]
},
"ProGen2": {
"pearson": [
0.4123995813840578,
0.0359331617293333
],
"spearman": [
0.3933219647742625,
0.0297316882664521
],
"rmse": [
1.1653628337698958,
0.0531596683904306
]
},
"AntiBERTy": {
"pearson": [
0.5320542866676312,
0.1108685997238828
],
"spearman": [
0.5172146797407249,
0.1172313497540197
],
"rmse": [
1.100228665984407,
0.0918019495235781
]
},
"ProtBERT": {
"pearson": [
0.819341728354072,
0.0253486118545338
],
"spearman": [
0.8090349090199496,
0.0268967334324502
],
"rmse": [
0.7702664546575165,
0.0466120077912966
]
},
"AntiBERTy-H/L\\n+ESM-2-Ag": {
"pearson": [
0.7185088907694643,
0.02461127113152863
],
"spearman": [
0.7023400213938253,
0.031580601879995895
],
"rmse": [
0.9221157273092846,
0.044163600100961965
]
},
"MINT": {
"pearson": [
0.8271321679712788,
0.0195961105862252
],
"spearman": [
0.8149267973584813,
0.0
],
"rmse": [
0.7660197496414185,
0.0
]
}
},
"pkd": {
"saaintdb": {
"n": 2575,
"min": 4.332547047110047,
"max": 13.468521082957745,
"mean": 8.634335426001249,
"median": 8.585026652029182,
"counts": [
3,
1,
5,
20,
33,
44,
71,
152,
217,
209,
282,
372,
321,
232,
220,
128,
95,
31,
53,
39,
36,
8,
1,
0,
2
],
"edges": [
4.332547047110047,
4.697986008543955,
5.063424969977863,
5.428863931411771,
5.794302892845679,
6.159741854279587,
6.525180815713495,
6.890619777147403,
7.256058738581311,
7.621497700015219,
7.986936661449127,
8.352375622883034,
8.717814584316942,
9.08325354575085,
9.44869250718476,
9.814131468618665,
10.179570430052575,
10.54500939148648,
10.91044835292039,
11.275887314354298,
11.641326275788206,
12.006765237222114,
12.372204198656021,
12.73764316008993,
13.103082121523837,
13.468521082957745
],
"nano": 662,
"antibody": 1913
},
"sabdab": {
"n": 578,
"min": 3.6943535804748535,
"max": 11.769551277160645,
"mean": 8.055658188658189,
"median": 8.058112144470215,
"counts": [
4,
1,
6,
1,
13,
12,
17,
18,
32,
32,
37,
33,
56,
49,
57,
34,
47,
29,
20,
21,
15,
21,
10,
7,
6
],
"edges": [
3.6943535804748535,
4.017361488342285,
4.3403693962097165,
4.663377304077148,
4.98638521194458,
5.309393119812012,
5.632401027679443,
5.955408935546876,
6.278416843414307,
6.601424751281739,
6.92443265914917,
7.247440567016602,
7.570448474884033,
7.893456382751465,
8.216464290618898,
8.53947219848633,
8.862480106353761,
9.185488014221193,
9.508495922088624,
9.831503829956056,
10.154511737823487,
10.477519645690919,
10.80052755355835,
11.123535461425782,
11.446543369293213,
11.769551277160645
]
},
"abbind": {
"n": 1089,
"min": 1.9791179895401,
"max": 11.786746978759766,
"mean": 7.029890592104804,
"median": 6.882932662963867,
"counts": [
32,
4,
0,
1,
4,
60,
43,
34,
49,
99,
94,
82,
80,
73,
71,
67,
61,
50,
55,
26,
20,
23,
24,
21,
16
],
"edges": [
1.9791179895401,
2.3714231491088866,
2.763728308677673,
3.15603346824646,
3.5483386278152467,
3.940643787384033,
4.33294894695282,
4.725254106521607,
5.117559266090393,
5.509864425659179,
5.902169585227966,
6.294474744796753,
6.68677990436554,
7.079085063934326,
7.471390223503113,
7.863695383071899,
8.256000542640686,
8.648305702209473,
9.040610861778259,
9.432916021347047,
9.825221180915833,
10.21752634048462,
10.609831500053406,
11.002136659622193,
11.39444181919098,
11.786746978759766
]
},
"skempi": {
"n": 387,
"min": 3.848284959793091,
"max": 12.292521476745604,
"mean": 8.246533254628341,
"median": 8.143704414367676,
"counts": [
3,
0,
0,
4,
6,
4,
5,
18,
16,
23,
28,
35,
77,
67,
14,
11,
8,
13,
5,
11,
23,
4,
3,
1,
8
],
"edges": [
3.848284959793091,
4.186054420471192,
4.523823881149292,
4.861593341827392,
5.199362802505493,
5.537132263183594,
5.874901723861694,
6.212671184539794,
6.550440645217895,
6.888210105895996,
7.225979566574097,
7.5637490272521966,
7.901518487930297,
8.239287948608398,
8.577057409286498,
8.9148268699646,
9.2525963306427,
9.5903657913208,
9.928135251998901,
10.265904712677,
10.603674173355103,
10.941443634033202,
11.279213094711302,
11.616982555389402,
11.954752016067504,
12.292521476745604
]
},
"benchmark": {
"n": 38,
"min": 5.328958400063679,
"max": 11.156361327230975,
"mean": 8.83928870355694,
"median": 8.873045589101903,
"counts": [
1,
0,
0,
1,
1,
1,
2,
0,
1,
0,
1,
3,
3,
2,
3,
1,
2,
0,
2,
4,
2,
4,
1,
2,
1
],
"edges": [
5.328958400063679,
5.562054517150371,
5.7951506342370624,
6.0282467513237545,
6.261342868410447,
6.494438985497139,
6.72753510258383,
6.960631219670522,
7.193727336757214,
7.426823453843905,
7.659919570930597,
7.8930156880172895,
8.126111805103982,
8.359207922190674,
8.592304039277366,
8.825400156364058,
9.058496273450748,
9.29159239053744,
9.524688507624132,
9.757784624710824,
9.990880741797515,
10.223976858884207,
10.457072975970899,
10.690169093057591,
10.923265210144283,
11.156361327230975
]
}
}
}''')
MET=[('pearson','Pearson r'),('spearman','Spearman ρ'),('rmse',f'RMSE ({PKD})')]
print('ready; datasets embedded:',list(DATA.keys()))
# Out:
# ready; datasets embedded: ['arch', 'fisher', 'nano', 'nano_fold', 'mvsf', 'transfer', 'gating', 'stream', 'cdrreg', 'topk', 'plm', 'pkd']

# %% [markdown]
# ---
# ## Panel 1 | Datasets and pK_d distributions

# %%
d=DATA['pkd']; dss=['saaintdb','sabdab','abbind','skempi','benchmark']
names={'saaintdb':'SAaIntDB','sabdab':'SAbDab','abbind':'AB-Bind','skempi':'SKEMPI','benchmark':'Benchmark'}
cols=seq(len(dss),'viridis')
fig=plt.figure(figsize=(7.2,4.4)); gs=fig.add_gridspec(2,3,height_ratios=[1.1,1])
# a) overlaid/normalised histograms
axa=fig.add_subplot(gs[0,:])
for ds,c in zip(dss,cols):
    e=np.array(d[ds]['edges']); ct=np.array(d[ds]['counts'],float); ct=ct/ct.sum()
    ctr=(e[:-1]+e[1:])/2; axa.plot(ctr,ct,color=c,lw=1.3,label=f"{names[ds]} (n={d[ds]['n']})")
axa.set_xlabel(f'Measured {PKD}'); axa.set_ylabel('frequency'); axa.legend(fontsize=5.6,ncol=2)
axa.set_title('Affinity distribution across datasets',fontsize=8,loc='left'); panel(axa,'a')
# b) dataset sizes
axb=fig.add_subplot(gs[1,0]); axb.bar(range(len(dss)),[d[x]['n'] for x in dss],color=cols,alpha=0.9)
axb.set_xticks(range(len(dss))); axb.set_xticklabels([names[x] for x in dss],rotation=35,ha='right',fontsize=5.6)
axb.set_ylabel('# complexes'); axb.set_yscale('log'); axb.set_title('Dataset size',fontsize=8,loc='left'); panel(axb,'b')
for i,x in enumerate(dss): axb.text(i,d[x]['n'],str(d[x]['n']),ha='center',va='bottom',fontsize=5)
# c) antibody vs nanobody composition (SAaIntDB)
axc=fig.add_subplot(gs[1,1]); sa=d['saaintdb']
axc.bar([0,1],[sa['antibody'],sa['nano']],color=seq(2,'viridis'),alpha=0.9)
axc.set_xticks([0,1]); axc.set_xticklabels(['Antibody\n(paired)','Nanobody\n(VHH)'],fontsize=6)
axc.set_ylabel('# complexes (SAaIntDB)'); axc.set_title('Composition',fontsize=8,loc='left'); panel(axc,'c')
for i,v in enumerate([sa['antibody'],sa['nano']]): axc.text(i,v,str(v),ha='center',va='bottom',fontsize=6)
# d) pKd range table-like bars (min..max with mean)
axd=fig.add_subplot(gs[1,2])
for i,ds in enumerate(dss):
    axd.plot([d[ds]['min'],d[ds]['max']],[i,i],color=cols[i],lw=3,solid_capstyle='round')
    axd.plot(d[ds]['mean'],i,'o',color='k',ms=3)
axd.set_yticks(range(len(dss))); axd.set_yticklabels([names[x] for x in dss],fontsize=5.6)
axd.set_xlabel(f'{PKD} range (• = mean)'); axd.set_title('Dynamic range',fontsize=8,loc='left'); panel(axd,'d')
plt.tight_layout(rect=[0,0,1,0.97]); save(fig,'panel1_data'); plt.show()
# Out:
# C:\Users\hs494\AppData\Local\Temp\ipykernel_45820\3426101372.py:15: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   def seq(n,cmap='viridis',lo=0.15,hi=0.9): return [cm.get_cmap(cmap)(x) for x in np.linspace(lo,hi,n)]
# C:\Users\hs494\AppData\Local\Temp\ipykernel_45820\3426101372.py:15: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   def seq(n,cmap='viridis',lo=0.15,hi=0.9): return [cm.get_cmap(cmap)(x) for x in np.linspace(lo,hi,n)]
# saved panel1_data

# %% [markdown]
# ---
# ## Panel 2 | Main comparison — architecture (a), antibody vs nanobody (b), vs MVSF-AB (c), overall vs intra-target (d)

# %%
fig=plt.figure(figsize=(7.5,8.6)); gs=fig.add_gridspec(3,3,hspace=0.78,wspace=0.55)
# a) architecture: random+cold, Ours/Two/Concat, 3 metrics
A=DATA['arch']; models=['Ours','Two-stream','Concat+MLP']; mc={'Ours':OURS,'Two-stream':TWO,'Concat+MLP':CONCAT}
for ci,(mk,ml) in enumerate(MET):
    ax=fig.add_subplot(gs[0,ci]); x=np.arange(3); w=0.38
    rv=[A[mk][m]['random'][0] for m in models]; re_=[A[mk][m]['random'][1] for m in models]
    cv=[A[mk][m]['cold'][0] for m in models];   ce=[A[mk][m]['cold'][1] for m in models]
    ax.bar(x-w/2,rv,w,yerr=re_,color=[mc[m] for m in models],alpha=0.95,error_kw=dict(lw=0.7,capsize=2))
    ax.bar(x+w/2,cv,w,yerr=ce,color=[mc[m] for m in models],alpha=0.55,hatch='xxx',edgecolor='white',error_kw=dict(lw=0.7,capsize=2))
    ax.set_xticks(x); ax.set_xticklabels(models,rotation=22,ha='right',fontsize=5.6); ax.set_ylabel(ml)
    ax.set_title(ml,fontsize=7.5)
    if ci==0: panel(ax,'a')
    if ci==1:
        from matplotlib.patches import Patch
        lg=[Patch(facecolor='0.62',edgecolor='0.3',label='random'),Patch(facecolor='0.62',edgecolor='0.3',hatch='xxx',label='cold')]
        ax.legend(handles=lg,fontsize=6.2,loc='lower center',bbox_to_anchor=(0.5,1.20),ncol=2,frameon=False,columnspacing=1.8,handlelength=1.4)
# b) antibody vs nanobody — 3 metrics, one subplot each, error bars across folds
NF=DATA['nano_fold']; grp=['Overall','Antibody','Nanobody']; gcol={'Overall':MVSF,'Antibody':TWO,'Nanobody':C4}
for ci,(mk,ml) in enumerate(MET):
    ax=fig.add_subplot(gs[1,ci]); x=np.arange(3)
    v=[NF[g][mk][0] for g in grp]; e=[NF[g][mk][1] for g in grp]
    ax.bar(x,v,yerr=e,color=[gcol[g] for g in grp],alpha=0.95,width=0.6,error_kw=dict(lw=0.7,capsize=3))
    ax.set_xticks(x); ax.set_xticklabels(grp,rotation=18,ha='right',fontsize=5.8); ax.set_ylabel(ml); ax.set_title(ml,fontsize=7.5)
    for i,g in enumerate(grp): ax.text(i,0.02,f"n={NF[g]['n']}",ha='center',fontsize=4.6,color='white')
    if ci==0: panel(ax,'b')
# c) Ours vs MVSF (Pearson + RMSE only; MVSF has no Spearman)
V=DATA['mvsf']; dss=['sabdab','abbind','skempi','benchmark']; dn=['SAbDab','AB-Bind','SKEMPI','Bench']
for ci,(mk,ml) in enumerate([('pearson','Pearson r'),('rmse',f'RMSE ({PKD})')]):
    ax=fig.add_subplot(gs[2,ci]); x=np.arange(4); w=0.38
    ovr=[V[d]['ours'][mk][0] for d in dss]; oer=[(V[d]['ours'][mk][1] if V[d]['ours'][mk][1]==V[d]['ours'][mk][1] else 0) for d in dss]
    mv=[V[d]['mvsf'][mk] for d in dss]
    ax.bar(x-w/2,ovr,w,yerr=oer,color=OURS,alpha=0.95,error_kw=dict(lw=0.7,capsize=2),label='Ours')
    ax.bar(x+w/2,mv,w,color=MVSF,alpha=0.9,label='MVSF-AB')
    ax.set_xticks(x); ax.set_xticklabels(dn,rotation=22,ha='right',fontsize=5.6); ax.set_ylabel(ml)
    top=max(max(ovr),max(mv)); ax.set_ylim(0,top*1.32)
    ax.legend(fontsize=5.5,ncol=2,loc='lower center',bbox_to_anchor=(0.5,1.0),frameon=False,columnspacing=1.0,handlelength=1.2)
    if ci==0: panel(ax,'c')
# d) overall vs intra-target (all metrics) — beside c
F=DATA['fisher']; NF=DATA['nano_fold']; ax=fig.add_subplot(gs[2,2]); x=np.arange(3); w=0.38
mks=['pearson','spearman','rmse']
ov=[F[m]['overall'] for m in mks]; ove=[NF['Overall'][m][1] for m in mks]
it=[F[m]['intra'] for m in mks]; its=[F[m]['intra_std'] for m in mks]
ax.bar(x-w/2,ov,w,yerr=ove,color=MVSF,alpha=0.9,error_kw=dict(lw=0.7,capsize=2),label='Overall'); ax.bar(x+w/2,it,w,yerr=its,color=C3,alpha=0.9,error_kw=dict(lw=0.7,capsize=2),label='Intra-target')
ax.set_xticks(x); ax.set_xticklabels(['Pears.','Spear.','RMSE'],fontsize=5.8); ax.set_ylabel('value'); ax.set_ylim(0,1.55)
ax.legend(fontsize=5.5,ncol=2,loc='lower center',bbox_to_anchor=(0.5,1.0),frameon=False,columnspacing=1.0,handlelength=1.2); panel(ax,'d')
plt.tight_layout(rect=[0,0,1,0.975]); save(fig,'panel2_main'); plt.show()
# Out:
# C:\Users\hs494\AppData\Local\Temp\ipykernel_45820\198991979.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0,0,1,0.975]); save(fig,'panel2_main'); plt.show()
# saved panel2_main

# %% [markdown]
# ---
# ## Panel 3 | Protein-language-model comparison (all metrics)

# %%
P=DATA['plm']; order=['ESM-2','ProtBERT','MINT','AntiBERTy','ProGen2','AntiBERTy-H/L\n+ESM-2-Ag']
order=[p for p in order if p in P]; cols=seq(len(order),'cividis')
fig,axes=plt.subplots(1,3,figsize=(7.2,2.7))
for ax,(mk,ml) in zip(axes,MET):
    v=[P[p][mk][0] for p in order]; e=[P[p][mk][1] for p in order]
    ax.bar(range(len(order)),v,yerr=e,color=cols,alpha=0.95,error_kw=dict(lw=0.7,capsize=2))
    ax.set_xticks(range(len(order))); ax.set_xticklabels(order,rotation=30,ha='right',fontsize=5.2); ax.set_ylabel(ml)
    ax.set_title(ml,fontsize=7.5)
axes[0].text(-0.16,1.06,'',transform=axes[0].transAxes)
plt.tight_layout(rect=[0,0,1,0.95]); save(fig,'panel3_plm'); plt.show()
# Out:
# C:\Users\hs494\AppData\Local\Temp\ipykernel_45820\3426101372.py:15: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   def seq(n,cmap='viridis',lo=0.15,hi=0.9): return [cm.get_cmap(cmap)(x) for x in np.linspace(lo,hi,n)]
# saved panel3_plm

# %% [markdown]
# ---
# ## Panel 4 | Zero-shot & few-shot transfer (Pearson and Spearman labelled)

# %%
T=DATA['transfer']; DS=['1mlc','1n8z','4fqi','koenig','trastuzumab','warszawski']
fig,axes=plt.subplots(2,3,figsize=(9.6,5.6)); axes=axes.flatten()
for ax,ds,L in zip(axes,DS,'abcdef'):
    fr=T[ds]['frac']; pe=T[ds]['pearson']; ps=T[ds]['pearson_std']; sp=T[ds]['spearman']; ss=T[ds]['spearman_std']
    zi=[i for i,x in enumerate(fr) if x==0.0]; fi=[i for i,x in enumerate(fr) if x>0]
    if zi: ax.axhline(pe[zi[0]],color='#95a5a6',ls=':',lw=1,label=f'zero-shot r ({pe[zi[0]]:.2f})')
    xf=[int(fr[i]*100) for i in fi]
    ax.errorbar(xf,[pe[i] for i in fi],yerr=[ps[i] for i in fi],fmt='o-',color=OURS,lw=1.8,ms=5,capsize=3,label='few-shot r')
    ax.errorbar(xf,[sp[i] for i in fi],yerr=[ss[i] for i in fi],fmt='s--',color=TWO,lw=1.2,ms=4,capsize=3,label='few-shot ρ')
    ax.set_xlabel('Train %'); ax.set_ylabel('correlation (r, ρ)' if L in 'ad' else ''); ax.set_xticks([10,20,30])
    ax.set_title(f'{L}  {ds}',fontsize=8); ax.legend(fontsize=5.2,loc='best'); panel(ax,L)
plt.tight_layout(); save(fig,'panel4_transfer'); plt.show()
# Out:
# saved panel4_transfer

# %% [markdown]
# ---
# ## Panel 4b | Zero-shot & few-shot transfer (bar view, sequential colour)

# %%
import seaborn as sns
from matplotlib.patches import Patch
T=DATA['transfer']; DS=['1mlc','1n8z','4fqi','koenig','trastuzumab','warszawski']
fig,axes=plt.subplots(2,3,figsize=(9.6,5.6)); axes=axes.flatten()
CP='#4E79A7'; CS='#A0CBE8'   # Tableau blues (medium / light): Pearson / Spearman
for ax,ds,L in zip(axes,DS,'abcdef'):
    fr=T[ds]['frac']; pe=T[ds]['pearson']; ps=T[ds]['pearson_std']; sp=T[ds]['spearman']; ss=T[ds]['spearman_std']
    order=sorted(range(len(fr)),key=lambda i:fr[i])
    labels=['0%' if fr[i]==0 else f'{int(fr[i]*100)}%' for i in order]
    x=np.arange(len(order)); w=0.38; ek={'lw':0.8,'ecolor':'0.4'}
    ax.bar(x-w/2,[pe[i] for i in order],w,yerr=[ps[i] for i in order],capsize=2.2,color=CP,edgecolor='0.35',linewidth=0.6,error_kw=ek)
    ax.bar(x+w/2,[sp[i] for i in order],w,yerr=[ss[i] for i in order],capsize=2.2,color=CS,edgecolor='0.35',linewidth=0.6,error_kw=ek)
    ax.axhline(0,color='0.6',lw=0.6)
    ax.set_xticks(x); ax.set_xticklabels(labels); ax.set_xlabel('Training fraction')
    ax.set_ylabel('correlation (r, ρ)' if L in 'ad' else '')
    ax.set_title(f'{L}  {ds}',fontsize=8,loc='left'); ax.spines[['top','right']].set_visible(False); panel(ax,L)
leg=[Patch(facecolor=CP,edgecolor='0.35',label='Pearson r'),
     Patch(facecolor=CS,edgecolor='0.35',label='Spearman ρ')]
fig.legend(handles=leg,ncol=2,loc='upper center',bbox_to_anchor=(0.5,0.955),fontsize=7,frameon=False,columnspacing=1.8,handlelength=1.3)
plt.tight_layout(rect=[0,0,1,0.94]); save(fig,'panel4b_transfer_bars'); plt.show()
# Out:
# saved panel4b_transfer_bars

# %% [markdown]
# ---
# ## Panel 5 | Gating ablation & stream/CDR analyses (all metrics)

# %%
G=DATA['gating']; gorder=['learned','fixed','open','random','closed']
glab={'learned':'Learned','fixed':'Fixed','open':'Open','random':'Random','closed':'Closed'}
gcol=[OURS]+list(seq(3,'Blues',0.4,0.8))+[MVSF]
S=DATA['stream']; R=DATA['cdrreg']
fig=plt.figure(figsize=(7.2,5.4)); gs=fig.add_gridspec(2,3,hspace=0.6,wspace=0.5)
# a) gating, 3 metrics
for ci,(mk,ml) in enumerate(MET):
    ax=fig.add_subplot(gs[0,ci]); v=[G[m][mk][0] for m in gorder]; e=[G[m][mk][1] for m in gorder]
    ax.bar(range(5),v,yerr=e,color=gcol,alpha=0.95,error_kw=dict(lw=0.7,capsize=2))
    ax.set_xticks(range(5)); ax.set_xticklabels([glab[m] for m in gorder],rotation=25,ha='right',fontsize=5.4); ax.set_ylabel(ml)
    ax.set_title(ml,fontsize=7.5)
    if ci==0: panel(ax,'a')
# b) stream interventions (Pearson / Spearman / RMSE)
ax=fig.add_subplot(gs[1,0]); conds=[r['condition'] for r in S]; x=np.arange(len(conds)); w=0.27
ax.bar(x-w,[r['pearson'] for r in S],w,yerr=[r['pearson_std'] for r in S],color=OURS,alpha=0.92,error_kw=dict(lw=0.5,capsize=2),label='Pearson r')
ax.bar(x,[r['spearman'] for r in S],w,yerr=[r['spearman_std'] for r in S],color=C2,alpha=0.92,error_kw=dict(lw=0.5,capsize=2),label='Spearman ρ')
ax.bar(x+w,[r['rmse'] for r in S],w,yerr=[r['rmse_std'] for r in S],color=C3,alpha=0.92,error_kw=dict(lw=0.5,capsize=2),label=f'RMSE ({PKD})')
ax.set_xticks(x); ax.set_xticklabels([c.replace('_',' ') for c in conds],rotation=30,ha='right',fontsize=5); ax.set_ylabel('value'); ax.set_ylim(0,1.55)
ax.legend(fontsize=4.6,ncol=3,loc='upper center',columnspacing=0.7,handlelength=1.0,handletextpad=0.4); ax.set_title('Stream interventions',fontsize=7); panel(ax,'b')
# c) per-CDR region (3 metrics)
ax=fig.add_subplot(gs[1,1]); cdr=[r['cdr'] for r in R]; x=np.arange(len(cdr)); w=0.26
for j,(mk,_) in enumerate(MET):
    ax.bar(x+(j-1)*w,[r[mk] for r in R],w,yerr=[r.get(mk+'_std',0) for r in R],color=[OURS,C2,C3][j],alpha=0.92,error_kw=dict(lw=0.5,capsize=2),label=dict(MET)[mk])
ax.set_xticks(x); ax.set_xticklabels(cdr,fontsize=5.6); ax.set_ylabel('value'); ax.set_ylim(0,0.84)
ax.legend(fontsize=4.6,ncol=3,loc='upper center',columnspacing=0.7,handlelength=1.0,handletextpad=0.4); ax.set_title('Per-CDR-region performance',fontsize=7); panel(ax,'c')
# d) top-K binder recovery
TK=DATA['topk']; ax=fig.add_subplot(gs[1,2]); x=np.arange(len(TK['k'])); w=0.2
ser=[('random','#bdc3c7','Random'),('zeroshot',C2,'Zero-shot'),('meanpool',MVSF,'Mean-pool'),('ours',OURS,'Ours')]
for j,(key,c,lab) in enumerate(ser): ax.bar(x+(j-1.5)*w,TK[key],w,color=c,alpha=0.92,label=lab)
ax.set_xticks(x); ax.set_xticklabels([f'Top-{int(k*100)}%' for k in TK['k']],fontsize=5.2); ax.set_ylabel('fraction recovered'); ax.set_ylim(0,0.72)
ax.legend(fontsize=4.4,ncol=2,loc='upper left',columnspacing=0.6,handlelength=1.0,handletextpad=0.3); ax.set_title('Top-K binder recovery (AAYL51)',fontsize=7); panel(ax,'d')
plt.tight_layout(rect=[0,0,1,0.96]); save(fig,'panel5_gating_supp'); plt.show()
# Out:
# C:\Users\hs494\AppData\Local\Temp\ipykernel_45820\3426101372.py:15: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   def seq(n,cmap='viridis',lo=0.15,hi=0.9): return [cm.get_cmap(cmap)(x) for x in np.linspace(lo,hi,n)]
# C:\Users\hs494\AppData\Local\Temp\ipykernel_45820\4144968369.py:32: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0,0,1,0.96]); save(fig,'panel5_gating_supp'); plt.show()
# saved panel5_gating_supp

# %% [markdown]
# ---
# ## Panel 6 | Mutational heatmaps (reads raw data files)

# %%
from matplotlib.colors import TwoSlopeNorm
hm=pd.read_csv(os.path.join(HERE,'advanced_results/cdr_heatmap_data_allcdr.csv'))
AAS=list('ACDEFGHIKLMNPQRSTVWY'); regs=['CDR-H1','CDR-H2','CDR-H3']
d=np.load(os.path.join(HERE,'experiments/results_allcdr_stats/aa_mutation_impact.npz'),allow_pickle=True)
AAo=list(d['aas']); true=d['true']; pred=d['pred']; err=d['err']
cat={**{a:'#c0392b' for a in 'RHKDE'},**{a:'#2980b9' for a in 'STNQ'},**{a:'#27ae60' for a in 'AVILMFYW'},**{a:'#8e44ad' for a in 'CGP'}}
fig=plt.figure(figsize=(8.6,6.6)); gs=fig.add_gridspec(2,3,hspace=0.55,wspace=0.32)
# a) saturation mutagenesis by CDR region (measured ΔpKd); x = wild-type AA + position
for ci,reg in enumerate(regs):
    ax=fig.add_subplot(gs[0,ci]); sub=hm[hm.cdr_region==reg]; pos=sorted(sub['mut_pos'].unique())
    Mx=np.full((len(AAS),len(pos)),np.nan)
    for j,p in enumerate(pos):
        for i,aa in enumerate(AAS):
            r=sub[(sub.mut_pos==p)&(sub.mut_aa==aa)]
            if len(r): Mx[i,j]=float(r['delta_pkd_true'].values[0])
    v=np.nanmax(np.abs(Mx)); v=float(v) if np.isfinite(v) and v>0.1 else 0.1
    im=ax.imshow(Mx,cmap='RdYlGn',norm=TwoSlopeNorm(0,-v,v),aspect='auto')
    ax.set_yticks(range(len(AAS))); ax.set_yticklabels(AAS,fontsize=4) if ci==0 else ax.set_yticks([])
    for t,a in zip(ax.get_yticklabels(),AAS): t.set_color(cat.get(a,'#000'))
    wtl=[f"{sub[sub.mut_pos==p]['wt_aa'].iloc[0]}{p}" if len(sub[sub.mut_pos==p]) else str(p) for p in pos]
    ax.set_xticks(range(len(pos))); ax.set_xticklabels(wtl,fontsize=4,rotation=90); ax.set_title(reg,fontsize=7.5)
    ax.set_xlabel('wild-type residue + position',fontsize=5.5)
    if ci==0: ax.set_ylabel('mutant AA'); panel(ax,'a')
    fig.colorbar(im,ax=ax,fraction=0.046,pad=0.02).ax.tick_params(labelsize=4)
# b) AA 20x20 true / predicted / error — category-coloured AA labels
for ci,(Mx,ttl,cmap) in enumerate([(true,'True ΔpKd','RdYlGn'),(pred,'Predicted ΔpKd','RdYlGn'),(err,'Error (true − pred)','coolwarm')]):
    ax=fig.add_subplot(gs[1,ci]); v=np.nanmax(np.abs(Mx)); v=float(v) if np.isfinite(v) and v>1e-9 else 1.0
    im=ax.imshow(Mx,cmap=cmap,norm=TwoSlopeNorm(0,-v,v),aspect='auto')
    ax.set_xticks(range(len(AAo))); ax.set_xticklabels(AAo,fontsize=4.5)
    ax.set_yticks(range(len(AAo))); ax.set_yticklabels(AAo,fontsize=4.5) if ci==0 else ax.set_yticks([])
    for t,a in zip(ax.get_xticklabels(),AAo): t.set_color(cat.get(a,'#000'))
    if ci==0:
        for t,a in zip(ax.get_yticklabels(),AAo): t.set_color(cat.get(a,'#000'))
        ax.set_ylabel('original AA'); panel(ax,'b')
    ax.set_xlabel('mutant AA'); ax.set_title(ttl,fontsize=7.5)
    fig.colorbar(im,ax=ax,fraction=0.046,pad=0.02).ax.tick_params(labelsize=4)
plt.tight_layout(rect=[0,0,1,0.94]); save(fig,'panel6_heatmaps'); plt.show()
# Out:
# C:\Users\hs494\AppData\Local\Temp\ipykernel_45820\1318378027.py:37: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0,0,1,0.94]); save(fig,'panel6_heatmaps'); plt.show()
# saved panel6_heatmaps

# %% [markdown]
# ---
# ## Panel 7 | Predicted vs measured scatters (reads raw data files)

# %%
from scipy.stats import pearsonr, spearmanr
import glob
def best_fold(d,fcol,tcol,pcol):
    bf=max(d[fcol].unique(),key=lambda fi:pearsonr(d[d[fcol]==fi][tcol],d[d[fcol]==fi][pcol])[0]); return d[d[fcol]==bf]
def scat(ax,t,p,title,lab):
    t=np.asarray(t,float); p=np.asarray(p,float); r=pearsonr(t,p)[0]; rho=spearmanr(t,p)[0]; rmse=float(np.sqrt(np.mean((t-p)**2)))
    xs=np.linspace(t.min(),t.max(),100); rng=np.random.default_rng(0); B=400; L=np.zeros((B,100))
    for b in range(B):
        idx=rng.integers(0,len(t),len(t)); m,c=np.polyfit(t[idx],p[idx],1); L[b]=m*xs+c
    ax.scatter(t,p,c=OURS,alpha=0.35,s=8,linewidths=0,rasterized=True)
    ax.plot(xs,L.mean(0),color='#7b241c',lw=1.2); ax.fill_between(xs,np.percentile(L,2.5,0),np.percentile(L,97.5,0),color=OURS,alpha=0.25)
    ax.set_xlabel(f'Measured {PKD}'); ax.set_ylabel(f'Predicted {PKD}')
    ax.set_title(f'{title}\nr={r:.3f}, ρ={rho:.3f}, RMSE={rmse:.2f} (n={len(t)})',fontsize=6.6); panel(ax,lab)
fig,axes=plt.subplots(2,3,figsize=(7.4,5.0)); axes=axes.flatten()
sa=best_fold(pd.read_csv(os.path.join(HERE,'results_saaintdb_allcdr/random/all_preds.csv')),'fold','binding_affinity','predicted_affinity')
scat(axes[0],sa['binding_affinity'],sa['predicted_affinity'],'SAaIntDB',' a')
for ax,ds,nm,lab in zip(axes[1:4],['sabdab','abbind','skempi'],['SAbDab','AB-Bind','SKEMPI'],[' b',' c',' d']):
    d=best_fold(pd.read_csv(os.path.join(HERE,f'experiments/results_allcdr_stats/oof_preds_{ds}.csv')),'fold','true','pred'); scat(ax,d['true'],d['pred'],nm,lab)
bps=glob.glob(os.path.join(HERE,'experiments/results/ours_allcdr_benchmark/seed_*/benchmark_preds.csv'))
bb=max(bps,key=lambda fp:pearsonr(pd.read_csv(fp)['true'],pd.read_csv(fp)['pred'])[0]); bd=pd.read_csv(bb)
scat(axes[4],bd['true'],bd['pred'],'Benchmark',' e')
axes[5].axis('off')
plt.tight_layout(rect=[0,0,1,0.93]); save(fig,'panel7_scatters'); plt.show()
# Out:
# saved panel7_scatters

# %%
import os
print('Panels saved to figures_panels/:')
for f in sorted(os.listdir(os.path.join(HERE,'figures_panels'))):
    if f.endswith('.png'): print(' ',f)
# Out:
# Panels saved to figures_panels/:
#   panel1_data.png
#   panel2_main.png
#   panel3_plm.png
#   panel4_transfer.png
#   panel4b_transfer_bars.png
#   panel5_gating_supp.png
#   panel6_heatmaps.png
#   panel7_scatters.png
